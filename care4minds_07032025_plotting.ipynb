# %% [markdown]
# # Tl;dr
# This notebook contains plotting/statistical analyses of StratifiedKFold results

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from statannotations.Annotator import Annotator
import matplotlib.patches as mpatches

# %%
def make_boxplot(df, groupby_plots_dict: dict, groupby_key: str, plots_key: str, metric: str):
    sns.set_theme(style='white')
    fig, axes = plt.subplots(2, 3, figsize=(20, 8))
    axes = axes.flatten()

    for i, p in enumerate(groupby_plots_dict[plots_key]):
        ax = axes[i]

        df_plotting = df[(df[plots_key] == p)][[plots_key, groupby_key, metric]].copy()

        dataset_order = (
            df_plotting.groupby(groupby_key)[metric]
            .median()
            .sort_values(ascending=False)
            .index
            .tolist()
        )

        palette = dict(zip(groupby_plots_dict[groupby_key], sns.color_palette("Set2", n_colors=len(groupby_plots_dict[groupby_key]))))

        sns.boxplot(
            x=groupby_key, y=metric, hue=groupby_key,
            data=df_plotting, ax=ax,
            order=dataset_order, palette=palette
        )

        ax.set_title(p)
        ax.set_xlabel('')
        if i != 0:
            ax.set_ylabel('')
        else:
            ax.set_ylabel(f'Cross-Validation {metric}')

        pairs = [(dataset_order[i], dataset_order[j]) for i in range(len(dataset_order)) for j in range(i+1, len(dataset_order))]

        annotator = Annotator(ax, pairs=pairs, data=df_plotting,
                              x=groupby_key, y=metric, hue=groupby_key,
                              order=dataset_order)
        annotator.configure(
            test='t-test_paired',
            comparisons_correction='Holm-Bonferroni',
            text_format='simple',
            loc='inside'
        )
        annotator.apply_and_annotate()

    patches = [mpatches.Patch(color=palette[label], label=label) for label in groupby_plots_dict[groupby_key]]
    fig.legend(
        handles=patches, title=groupby_key,
        loc='upper center', bbox_to_anchor=(0.5, 1.05), ncol=len(groupby_plots_dict[groupby_key]), frameon=False
    )

    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

# %% [markdown]
# # PCA

# %%
alldata = pd.read_csv('/Users/daisyliu/Desktop/Care4Minds/stratifiedkfold/care4minds_stratifiedkfold_all-data_Jun30.csv')
alldata.head()
# Out:
#   model        dataset    fold  train_acc  test_acc  train_auc  test_auc  \
# 0   KNN  no embeddings  fold_1   0.999095  0.658395   0.999998  0.728902
# 1   KNN  no embeddings  fold_2   0.999327  0.662924   0.999999  0.731424
# 2   KNN  no embeddings  fold_3   0.999239  0.662277   0.999999  0.728387
# 3   KNN  no embeddings  fold_4   0.999250  0.664180   0.999999  0.736009
# 4   KNN  no embeddings  fold_5   0.999184  0.665626   0.999999  0.728636
#
#    train_recall  test_recall  train_precision  test_precision  train_f1  \
# 0      0.998279     0.671301         0.999912        0.315858  0.999095
# 1      0.998742     0.672294         0.999912        0.319581  0.999327
# 2      0.998632     0.669911         0.999845        0.318658  0.999238
# 3      0.998632     0.684211         0.999867        0.322596  0.999249
# 4      0.998500     0.670109         0.999867        0.321364  0.999183
#
#     test_f1
# 0  0.429588
# 1  0.433225
# 2  0.431882
# 3  0.438463
# 4  0.434402

# %%
set(alldata['dataset'])
# Out:
# {'combined_combined_pca_128',
#  'combined_isolated_pca_128',
#  'combined_isolated_pca_256',
#  'combined_isolated_pca_512',
#  'no embeddings'}

# %%
alldata_plotting = alldata[(alldata['dataset'] != 'combined_combined_pca_128')].copy()

alldata_plotting.replace({
    'combined_isolated_pca_128': 'pca_128',
    'combined_isolated_pca_256': 'pca_256',
    'combined_isolated_pca_512': 'pca_512',
    'no embeddings': 'no embed'
    }, inplace=True)

# %%
groupby_plots_dict = {
    'dataset': ['pca_128', 'pca_256', 'pca_512', 'no embed'],
    'model': ['KNN', 'LR', 'RFC', 'ADA', 'XGB', 'LGC']
}
make_boxplot(df=alldata_plotting, groupby_plots_dict=groupby_plots_dict,
             groupby_key='dataset', plots_key='model', metric='test_auc')
# Out:
# no embed vs. pca_128: t-test paired samples with Holm-Bonferroni correction, P_val:3.370e-08 t=1.723e+01
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:1.660e-09 t=2.423e+01
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:2.251e-12 t=5.074e+01
# no embed vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:3.452e-10 t=2.891e+01
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:1.888e-13 t=6.687e+01
# no embed vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:1.757e-13 t=6.741e+01
# pca_256 vs. pca_128: t-test paired samples with Holm-Bonferroni correction, P_val:4.246e-01 t=-8.363e-01
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:5.046e-06 t=9.594e+00
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.124e-08 t=1.952e+01
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:2.261e-04 t=5.911e+00
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:6.641e-09 t=2.072e+01
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:4.112e-09 t=2.188e+01
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:2.926e-13 t=6.369e+01
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:1.349e-11 t=4.155e+01
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:3.028e-03 t=4.018e+00
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:2.456e-13 t=6.494e+01
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:2.128e-06 t=1.064e+01
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:8.215e-08 t=1.556e+01
# pca_256 vs. pca_128: t-test paired samples with Holm-Bonferroni correction, P_val:5.886e-01 t=5.609e-01
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:8.237e-01 t=2.293e-01
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.173e-11 t=4.221e+01
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:5.613e-01 t=6.031e-01
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.416e-11 t=4.133e+01
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:7.954e-12 t=4.408e+01
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:5.961e-03 t=3.577e+00
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:6.803e-04 t=5.061e+00
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.962e-10 t=3.080e+01
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:3.729e-06 t=9.950e+00
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.223e-10 t=3.248e+01
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:2.386e-10 t=3.014e+01
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:1.393e-03 t=4.546e+00
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:1.327e-05 t=8.525e+00
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:7.209e-11 t=3.446e+01
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:2.343e-06 t=1.052e+01
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:4.193e-11 t=3.661e+01
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:5.382e-11 t=3.560e+01

# %%
make_boxplot(df=alldata_plotting, groupby_plots_dict=groupby_plots_dict,
             groupby_key='dataset', plots_key='model', metric='test_recall')
# Out:
# no embed vs. pca_128: t-test paired samples with Holm-Bonferroni correction, P_val:2.755e-17 t=1.786e+02
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:1.413e-01 t=1.613e+00
# pca_512 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:3.445e-03 t=3.933e+00
# no embed vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:8.623e-13 t=5.647e+01
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:6.907e-09 t=2.063e+01
# no embed vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:4.411e-16 t=1.312e+02
# pca_512 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:8.890e-01 t=1.436e-01
# pca_256 vs. pca_128: t-test paired samples with Holm-Bonferroni correction, P_val:9.104e-03 t=3.309e+00
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:6.472e-10 t=2.694e+01
# pca_512 vs. pca_128: t-test paired samples with Holm-Bonferroni correction, P_val:3.029e-01 t=1.093e+00
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.032e-09 t=2.557e+01
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:2.689e-09 t=2.295e+01
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:1.053e-07 t=1.512e+01
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.128e-01 t=1.757e+00
# no embed vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:3.473e-02 (ns) t=2.485e+00
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:2.446e-04 t=5.847e+00
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:1.936e-06 t=1.076e+01
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:2.719e-08 t=1.766e+01
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:3.572e-01 t=9.703e-01
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:4.481e-02 (ns) t=2.329e+00
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.457e-03 t=4.515e+00
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:3.825e-02 (ns) t=2.426e+00
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:6.008e-04 t=5.153e+00
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:2.455e-04 t=5.844e+00
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:9.839e-01 t=2.071e-02
# pca_512 vs. pca_128: t-test paired samples with Holm-Bonferroni correction, P_val:1.110e-02 t=3.185e+00
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:6.406e-07 t=1.226e+01
# pca_256 vs. pca_128: t-test paired samples with Holm-Bonferroni correction, P_val:6.510e-03 t=3.521e+00
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:3.457e-07 t=1.318e+01
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:3.733e-07 t=1.306e+01
# pca_256 vs. pca_128: t-test paired samples with Holm-Bonferroni correction, P_val:9.835e-02 t=1.844e+00
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:1.665e-01 t=1.505e+00
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:3.680e-08 t=1.706e+01
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:5.943e-03 t=3.579e+00
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:8.833e-08 t=1.543e+01
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:3.413e-08 t=1.720e+01

# %%
make_boxplot(df=alldata_plotting, groupby_plots_dict=groupby_plots_dict,
             groupby_key='dataset', plots_key='model', metric='test_precision')
# Out:
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:2.206e-04 t=5.930e+00
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.468e-06 t=1.112e+01
# no embed vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:6.190e-01 t=5.150e-01
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:7.057e-11 t=3.454e+01
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:2.526e-07 t=1.367e+01
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:1.353e-07 t=1.469e+01
# no embed vs. pca_128: t-test paired samples with Holm-Bonferroni correction, P_val:2.386e-01 t=1.262e+00
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:9.225e-01 t=1.001e-01
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:1.557e-02 (ns) t=2.975e+00
# no embed vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:2.706e-01 t=1.174e+00
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:1.320e-02 (ns) t=3.077e+00
# no embed vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:5.549e-02 t=2.198e+00
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:9.222e-03 t=3.301e+00
# no embed vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:7.755e-03 t=3.410e+00
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:1.434e-10 t=3.190e+01
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:6.575e-09 t=2.074e+01
# no embed vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:2.728e-06 t=1.033e+01
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:1.116e-12 t=5.487e+01
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:5.497e-01 t=-6.215e-01
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:4.671e-01 t=7.593e-01
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.527e-10 t=3.168e+01
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:8.209e-01 t=2.331e-01
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:4.700e-10 t=2.793e+01
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:6.737e-10 t=2.682e+01
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:4.706e-01 t=7.532e-01
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:9.207e-04 t=4.840e+00
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:5.466e-06 t=9.502e+00
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:8.812e-05 t=6.704e+00
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:2.976e-07 t=1.341e+01
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:3.518e-07 t=1.315e+01
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:5.552e-02 t=2.198e+00
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:1.626e-05 t=8.314e+00
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:2.125e-07 t=1.394e+01
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:1.795e-04 t=6.099e+00
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:8.704e-08 t=1.545e+01
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:5.100e-08 t=1.643e+01

# %%
make_boxplot(df=alldata_plotting, groupby_plots_dict=groupby_plots_dict,
             groupby_key='dataset', plots_key='model', metric='test_f1')
# Out:
# no embed vs. pca_128: t-test paired samples with Holm-Bonferroni correction, P_val:3.507e-14 t=8.065e+01
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:1.036e-05 t=8.789e+00
# pca_512 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:1.424e-01 t=1.608e+00
# no embed vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:2.999e-11 t=3.801e+01
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:2.671e-09 t=2.297e+01
# no embed vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:1.501e-13 t=6.860e+01
# pca_256 vs. pca_128: t-test paired samples with Holm-Bonferroni correction, P_val:6.140e-01 t=5.224e-01
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:7.440e-02 t=2.018e+00
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:2.191e-05 t=8.010e+00
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:4.823e-02 (ns) t=2.284e+00
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:4.345e-06 t=9.769e+00
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:7.143e-06 t=9.198e+00
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.590e-03 t=4.454e+00
# no embed vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:9.036e-02 t=1.897e+00
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:9.292e-10 t=2.587e+01
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:3.271e-09 t=2.245e+01
# no embed vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:1.937e-05 t=8.134e+00
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:1.462e-11 t=4.118e+01
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:8.971e-01 t=-1.331e-01
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:2.312e-01 t=1.284e+00
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:2.805e-10 t=2.959e+01
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:3.699e-01 t=9.439e-01
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.944e-09 t=2.381e+01
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:3.048e-09 t=2.263e+01
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:5.503e-01 t=-6.205e-01
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:5.336e-03 t=3.648e+00
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:9.487e-07 t=1.171e+01
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:3.284e-03 t=3.964e+00
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.177e-07 t=1.493e+01
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.861e-07 t=1.416e+01
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:3.705e-01 t=9.425e-01
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:4.266e-05 t=7.363e+00
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:5.849e-08 t=1.618e+01
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:7.862e-04 t=4.955e+00
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:3.325e-08 t=1.725e+01
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:3.639e-08 t=1.708e+01

# %%
make_boxplot(df=alldata_plotting, groupby_plots_dict=groupby_plots_dict,
             groupby_key='dataset', plots_key='model', metric='test_acc')
# Out:
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:4.108e-03 t=3.817e+00
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:1.216e-04 t=6.426e+00
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.572e-10 t=3.158e+01
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:9.729e-05 t=6.618e+00
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.295e-14 t=9.011e+01
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:8.244e-16 t=1.224e+02
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:5.201e-01 t=6.693e-01
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:6.518e-03 t=3.520e+00
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:2.923e-05 t=7.725e+00
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:4.018e-03 t=3.832e+00
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.102e-05 t=8.722e+00
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:2.433e-06 t=1.047e+01
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:1.912e-08 t=1.838e+01
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:6.073e-10 t=2.714e+01
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:2.130e-08 t=1.815e+01
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:3.294e-13 t=6.285e+01
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.054e-09 t=2.551e+01
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.019e-10 t=3.315e+01
# pca_512 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:7.467e-01 t=-3.331e-01
# pca_256 vs. pca_128: t-test paired samples with Holm-Bonferroni correction, P_val:3.253e-01 t=1.040e+00
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:9.465e-13 t=5.588e+01
# pca_512 vs. pca_128: t-test paired samples with Holm-Bonferroni correction, P_val:7.145e-01 t=3.776e-01
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:7.965e-13 t=5.697e+01
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.453e-12 t=5.328e+01
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:5.932e-02 t=2.157e+00
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:2.477e-04 t=5.837e+00
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:2.207e-10 t=3.040e+01
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:1.184e-05 t=8.646e+00
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:3.208e-11 t=3.772e+01
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:3.156e-11 t=3.779e+01
# pca_128 vs. pca_256: t-test paired samples with Holm-Bonferroni correction, P_val:9.523e-03 t=3.280e+00
# pca_256 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:5.133e-05 t=7.191e+00
# pca_512 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:3.829e-11 t=3.698e+01
# pca_128 vs. pca_512: t-test paired samples with Holm-Bonferroni correction, P_val:7.438e-05 t=6.854e+00
# pca_256 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:2.664e-11 t=3.851e+01
# pca_128 vs. no embed: t-test paired samples with Holm-Bonferroni correction, P_val:1.324e-11 t=4.164e+01

# %% [markdown]
# # Leadtimes

# %%
leadtimes = pd.read_csv('/Users/daisyliu/Desktop/Care4Minds/stratifiedkfold/care4minds_stratifiedcv_lead-times_pca_128_scores_Jun30.csv')
leadtimes.head()
# Out:
#   model           dataset    fold  train_acc  test_acc  train_auc  test_auc  \
# 0   KNN  3_months_pca_128  fold_1        1.0  0.819466        1.0  0.677117
# 1   KNN  3_months_pca_128  fold_2        1.0  0.820144        1.0  0.674191
# 2   KNN  3_months_pca_128  fold_3        1.0  0.824707        1.0  0.664236
# 3   KNN  3_months_pca_128  fold_4        1.0  0.822597        1.0  0.659805
# 4   KNN  3_months_pca_128  fold_5        1.0  0.827307        1.0  0.664288
#
#    train_recall  test_recall  train_precision  test_precision  train_f1  \
# 0           1.0     0.263729              1.0        0.340332       1.0
# 1           1.0     0.251525              1.0        0.337273       1.0
# 2           1.0     0.218718              1.0        0.336991       1.0
# 3           1.0     0.210580              1.0        0.325301       1.0
# 4           1.0     0.237030              1.0        0.355003       1.0
#
#     test_f1
# 0  0.297173
# 1  0.288155
# 2  0.265268
# 3  0.255661
# 4  0.284262

# %%
leadtimes_plotting = leadtimes.replace({'3_months_pca_128': '3mo',
                                        '6_months_pca_128': '6mo',
                                        '12_months_pca_128': '12mo'}).copy()

groupby_plots_dict = {
    'dataset': ['3mo', '6mo', '12mo'],
    'model': ['KNN', 'LR', 'RFC', 'ADA', 'XGB', 'LGC']
}

# %%
make_boxplot(df=leadtimes_plotting, groupby_plots_dict=groupby_plots_dict,
             groupby_key='dataset', plots_key='model', metric='test_auc')
# Out:
# 3mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.822e-01 t=1.446e+00
# 12mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:7.591e-01 t=-3.162e-01
# 3mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.178e-01 t=1.729e+00
# 3mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.440e-01 t=1.600e+00
# 6mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:9.045e-01 t=-1.234e-01
# 3mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:3.299e-01 t=1.030e+00
# 12mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.551e-01 t=1.552e+00
# 6mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:6.541e-01 t=4.634e-01
# 12mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:5.119e-02 t=2.248e+00
# 12mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:3.263e-01 t=1.038e+00
# 6mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:5.109e-01 t=6.845e-01
# 12mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:8.144e-02 t=1.962e+00
# 12mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:5.386e-01 t=6.393e-01
# 6mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:6.176e-01 t=5.171e-01
# 12mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.351e-01 t=1.641e+00
# 12mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:4.186e-01 t=8.476e-01
# 6mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:6.648e-01 t=4.479e-01
# 12mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:7.865e-02 t=1.983e+00

# %%
make_boxplot(df=leadtimes_plotting, groupby_plots_dict=groupby_plots_dict,
             groupby_key='dataset', plots_key='model', metric='test_recall')
# Out:
# 12mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:7.419e-06 t=9.156e+00
# 6mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:2.886e-03 t=4.050e+00
# 12mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.820e-06 t=1.084e+01
# 3mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:7.409e-01 t=3.410e-01
# 12mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.042e-01 t=1.807e+00
# 3mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:8.941e-02 t=1.903e+00
# 6mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:7.554e-01 t=-3.212e-01
# 12mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:2.471e-01 t=1.238e+00
# 6mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:2.351e-01 t=1.273e+00
# 6mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:6.928e-01 t=-4.080e-01
# 12mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:3.889e-01 t=9.054e-01
# 6mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:7.934e-01 t=2.698e-01
# 6mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:9.333e-01 t=-8.611e-02
# 12mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:7.193e-01 t=-3.709e-01
# 6mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:6.982e-01 t=-4.004e-01
# 6mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:7.414e-01 t=3.403e-01
# 3mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:9.766e-01 t=-3.013e-02
# 6mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:7.274e-01 t=3.596e-01

# %%
make_boxplot(df=leadtimes_plotting, groupby_plots_dict=groupby_plots_dict,
             groupby_key='dataset', plots_key='model', metric='test_precision')
# Out:
# 3mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:2.277e-06 t=1.056e+01
# 6mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.190e-03 t=4.657e+00
# 3mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.281e-06 t=1.130e+01
# 3mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.874e-06 t=1.080e+01
# 6mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.847e-07 t=1.417e+01
# 3mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:8.673e-09 t=2.010e+01
# 3mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:7.430e-07 t=1.205e+01
# 6mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.099e-05 t=8.726e+00
# 3mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.699e-07 t=1.431e+01
# 3mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:2.551e-04 t=5.813e+00
# 6mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:7.652e-06 t=9.121e+00
# 3mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:4.985e-09 t=2.141e+01
# 3mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.170e-05 t=8.659e+00
# 6mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:6.694e-06 t=9.271e+00
# 3mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:6.414e-10 t=2.697e+01
# 3mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:3.403e-05 t=7.578e+00
# 6mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.456e-05 t=8.428e+00
# 3mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:3.523e-09 t=2.226e+01

# %%
make_boxplot(df=leadtimes_plotting, groupby_plots_dict=groupby_plots_dict,
             groupby_key='dataset', plots_key='model', metric='test_f1')
# Out:
# 12mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:2.343e-01 t=1.275e+00
# 6mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:3.436e-01 t=9.996e-01
# 12mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.577e-01 t=1.541e+00
# 3mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.876e-05 t=8.167e+00
# 6mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:9.401e-06 t=8.895e+00
# 3mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.625e-07 t=1.438e+01
# 3mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:5.529e-06 t=9.489e+00
# 6mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.852e-04 t=6.073e+00
# 3mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.750e-06 t=1.089e+01
# 3mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.635e-03 t=4.435e+00
# 6mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.417e-04 t=6.296e+00
# 3mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:4.645e-08 t=1.661e+01
# 3mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.072e-04 t=6.533e+00
# 6mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:5.585e-05 t=7.113e+00
# 3mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:2.099e-09 t=2.360e+01
# 3mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:9.650e-04 t=4.806e+00
# 6mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:8.854e-05 t=6.700e+00
# 3mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:2.202e-08 t=1.808e+01

# %%
make_boxplot(df=leadtimes_plotting, groupby_plots_dict=groupby_plots_dict,
             groupby_key='dataset', plots_key='model', metric='test_acc')
# Out:
# 3mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:2.951e-03 t=4.035e+00
# 6mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:2.004e-02 t=2.820e+00
# 3mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:6.677e-05 t=6.951e+00
# 12mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:6.259e-01 t=5.046e-01
# 3mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:3.802e-01 t=9.228e-01
# 12mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:7.101e-02 t=2.047e+00
# 12mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.322e-01 t=1.655e+00
# 3mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:4.724e-01 t=7.500e-01
# 12mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:2.610e-02 (ns) t=2.659e+00
# 12mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.412e-01 t=1.613e+00
# 6mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:2.387e-01 t=1.262e+00
# 12mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:1.204e-02 t=3.134e+00
# 12mo vs. 6mo: t-test paired samples with Holm-Bonferroni correction, P_val:2.123e-01 t=1.343e+00
# 6mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:3.752e-01 t=-9.328e-01
# 12mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:4.905e-01 t=7.188e-01
# 6mo vs. 12mo: t-test paired samples with Holm-Bonferroni correction, P_val:4.010e-01 t=-8.814e-01
# 12mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:2.799e-01 t=1.150e+00
# 6mo vs. 3mo: t-test paired samples with Holm-Bonferroni correction, P_val:9.102e-01 t=-1.160e-01
